# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# Basic graphs

# %%
x=np.array([1,2,3])
y=np.array([4,5,6])
plt.plot(x,y)
plt.xlabel("X AXIS!")
plt.ylabel("Y axis !")
plt.title("our first grpah ")

plt.show()
